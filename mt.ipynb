# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3], [4, 5, 6])
plt.show()
print("Matplotlib is ready!")
# Out:
# Matplotlib is ready!

# %% [markdown]
# # Matplotlib Class
#
# This notebook demonstrates basic matplotlib usage.
#
# Repository: [GitHub](https://github.com/mana629/matplotlib_class.git)
